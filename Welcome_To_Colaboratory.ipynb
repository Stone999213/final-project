# %% [markdown]
# <a href="https://colab.research.google.com/github/Stone999213/final-project/blob/main/Welcome_To_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Welcome to Colab!</h1>
# </div>
#
# If you're already familiar with Colab, check out this video to learn about interactive tables, the executed code history view, and the command palette.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=rNgswRZ2C1Y" target="_blank">
#   <img alt='Thumbnail for a video showing 3 cool Google Colab features' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>What is Colab?</h2>
# </div>
#
# Colab, or "Colaboratory", allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Access to GPUs free of charge
# - Easy sharing
#
# Whether you're a **student**, a **data scientist** or an **AI researcher**, Colab can make your work easier. Watch [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) to learn more, or just get started below!

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## **Getting started**
# </div>
#
# The document you are reading is not a static web page, but an interactive environment called a **Colab notebook** that lets you write and execute code.
#
# For example, here is a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut "Command/Ctrl+Enter". To edit the code, just click the cell and start editing.
#
# Variables that you define in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Colab notebooks allow you to combine **executable code** and **rich text** in a single document, along with **images**, **HTML**, **LaTeX** and more. When you create your own Colab notebooks, they are stored in your Google Drive account. You can easily share your Colab notebooks with co-workers or friends, allowing them to comment on your notebooks or even edit them. To learn more, see [Overview of Colab](/notebooks/basic_features_overview.ipynb). To create a new Colab notebook you can use the File menu above, or use the following link: [create a new Colab notebook](http://colab.research.google.com#create=true).
#
# Colab notebooks are Jupyter notebooks that are hosted by Colab. To learn more about the Jupyter project, see [jupyter.org](https://www.jupyter.org).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Data science
# </div>
#
# With Colab you can harness the full power of popular Python libraries to analyze and visualize data. The code cell below uses **numpy** to generate some random data, and uses **matplotlib** to visualize it. To edit the code, just click the cell and start editing.

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %% [markdown]
# You can import your own data into Colab notebooks from your Google Drive account, including from spreadsheets, as well as from Github and many other sources. To learn more about importing data, and how Colab can be used for data science, see the links below under [Working with Data](#working-with-data).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Machine learning
# </div>
#
# With Colab you can import an image dataset, train an image classifier on it, and evaluate the model, all in just [a few lines of code](https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb). Colab notebooks execute code on Google's cloud servers, meaning you can leverage the power of Google hardware, including [GPUs and TPUs](#using-accelerated-hardware), regardless of the power of your machine. All you need is a browser.

# %% [markdown]
# Colab is used extensively in the machine learning community with applications including:
# - Getting started with TensorFlow
# - Developing and training neural networks
# - Experimenting with TPUs
# - Disseminating AI research
# - Creating tutorials
#
# To see sample Colab notebooks that demonstrate machine learning applications, see the [machine learning examples](#machine-learning-examples) below.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## More Resources
#
# ### Working with Notebooks in Colab
#
# </div>
#
# - [Overview of Colaboratory](/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
# - <img src="/img/new.png" height="20px" align="left" hspace="4px" alt="New"></img>
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### Working with Data
# </div>
#
# - [Loading data: Drive, Sheets, and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualizing data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### Machine Learning Crash Course
#
# <div>
#
# These are a few of the notebooks from Google's online Machine Learning course. See the [full course website](https://developers.google.com/machine-learning/crash-course/) for more.
# - [Intro to Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Linear regression with tf.keras using synthetic data](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### Using Accelerated Hardware
# </div>
#
# - [TensorFlow with GPUs](/notebooks/gpu.ipynb)
# - [TensorFlow with TPUs](/notebooks/tpu.ipynb)

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### Featured examples
#
# </div>
#
# - [NeMo Voice Swap](https://colab.research.google.com/github/NVIDIA/NeMo/blob/stable/tutorials/VoiceSwapSample.ipynb): Use Nvidia's NeMo conversational AI Toolkit to swap a voice in an audio fragment with a computer generated one.
#
# - [Retraining an Image Classifier](https://tensorflow.org/hub/tutorials/tf2_image_retraining): Build a Keras model on top of a pre-trained image classifier to distinguish flowers.
# - [Text Classification](https://tensorflow.org/hub/tutorials/tf2_text_classification): Classify IMDB movie reviews as either *positive* or *negative*.
# - [Style Transfer](https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization): Use deep learning to transfer style between images.
# - [Multilingual Universal Sentence Encoder Q&A](https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa): Use a machine learning model to answer questions from the SQuAD dataset.
# - [Video Interpolation](https://tensorflow.org/hub/tutorials/tweening_conv3d): Predict what happened in a video between the first and the last frame.

# %%
import pandas as pd
import matplotlib.pyplot as plt
#make list to be used in the x and y coordinates of the bar graph

df=pd.read_csv('https://raw.githubusercontent.com/Stone999213/final-project/main/spotify_final%20project.csv')
#sort the valuse in decending order to get the top 10 most popular artist
#df=df.sort_values(by="popularity",axis=0,ascending=False)
df=df.head(200)
popularity=df["popularity"]
speechiness=df["speechiness"] 
fig, ax=plt.subplots()
ax.scatter(speechiness,popularity,color="red")
ax.set_ylabel("Popularity")
ax.set_xlabel("Speechiness")
ax.set_title("coorelation of popularity and speechiness")
print("There is no apparent relationship between these two attributes ")
print("If this plot tells us anything, the words of the song don't seem to make much of a difference to whether of not a song is popular")
# Out:
# There is no apparent relationship between these two attributes

# %% [markdown]
# When I first approached this project I assumed that there would be a strong correlation between popularity and one or several of the attributes listed in the spotify dataset. That is, if an artist's song has a high popularity rating, why is that so?. To my disappointment, I wasn't able to find that correlation. That is not
# to say that one does exist, it just that, if one exist, I don't the skill yet to demonstrate it. I found that the strongest correlation is between energy and loudness which intuitively makes sense and can easily be visualy  demonstrated graphically

# %%
import pandas as pd
import matplotlib.pyplot as plt
#make list to be used in the x and y coordinates of the bar graph

loudness_list=[]  
popularity_list=[] 
df=pd.read_csv('https://raw.githubusercontent.com/Stone999213/final-project/main/spotify_final%20project.csv')
#sort the valuse in decending order to get the top 10 most popular artist
#df=df.sort_values(by="popularity",axis=0,ascending=False)
df=df.head(200)
energy=df["energy"]
loudness = df["loudness"] 
 
fig, ax=plt.subplots()
ax.scatter(loudness,energy,color="red")
ax.set_xlabel("Loudness")
ax.set_ylabel("Energy")
ax.set_title("Correlation between energy and loudness")
print("There is a definite correlation between energy and loudness of .76")

print("The x axis values are desplayed as minus values, the least negative values represent the highest level volumne")
# Out:
# There is a definite correlation between energy and loudness of .76

# %%
import pandas as pd
import matplotlib.pyplot as plt
#make list to be used in the x and y coordinates of the bar graph

loudness_list=[]  
popularity_list=[] 
df=pd.read_csv('https://raw.githubusercontent.com/Stone999213/final-project/main/spotify_final%20project.csv')
#sort the valuse in decending order to get the top 10 most popular artist
df=df.sort_values(by="popularity",axis=0,ascending=False)
df=df.head(10)
energy=df["energy"]
loudness = df["loudness"] 
 
fig, ax=plt.subplots()
plt.plot(loudness,energy,color="red")
ax.set_xlabel("Loudness")
ax.set_ylabel("Energy")
ax.set_title("Correlation between energy and loudness")
print("There is a definite correlation between energy and loudness of .76")

print("The x axis values are desplayed as minus values, the least negative values represent the highest level volumne")
# Out:
# There is a definite correlation between energy and loudness of .76
# The x axis values are desplayed as minus values, the least negative values represent the highest level volumne

# %%
from matplotlib.figure import LayoutEngine
import pandas as pd
import matplotlib.pyplot as plt

artist_list=[]
artist_count_list=[]
name_list=[]  
df=pd.read_csv('https://raw.githubusercontent.com/Stone999213/final-project/main/spotify_final%20project.csv')
#sort the valuse in decending order to get the top 10 most popular artist
df=df.sort_values(by="popularity",axis=0,ascending=False)
df=df.head(10)
popularity=df["popularity"]
artist_name=df["artists"].sort_values()
print(artist_name)
#create new data frame based of the occurences of number of times artist songs occured in the top 10
# of the original data frame 
df1=pd.DataFrame({"x":[1,3,4,2],"y":["Bizarrap","David Guetta;","Manuel Turizo","Sam Smith;Kim Petras"]})

fig, ax=plt.subplots()
ax.pie(df1["x"],labels=df1["y"],colors=["red","blue","green","yellow"],explode=[.02,.02,.04,.02],autopct="%1.1f%%")
       
ax.set_title("pie chart of artist's songs appearancee in the top 10 most popular")
# Out:
# 51664           Bizarrap;Quevedo
# 81210    David Guetta;Bebe Rexha
# 30003    David Guetta;Bebe Rexha
# 20008    David Guetta;Bebe Rexha
# 89411              Manuel Turizo
# 68303              Manuel Turizo
# 88410              Manuel Turizo
# 67356              Manuel Turizo
# 20001       Sam Smith;Kim Petras
# 81051       Sam Smith;Kim Petras
# Name: artists, dtype: object
# Text(0.5, 1.0, "pie chart of artist's songs appearancee in the top 10 most popular")

# %%
import pandas as pd
import matplotlib.pyplot as plt
#make list to be used in the x and y coordinates of the bar graph

loudness_list=[]  
popularity_list=[] 
df=pd.read_csv('https://raw.githubusercontent.com/Stone999213/final-project/main/spotify_final%20project.csv')
df.describe()
# Out:
#           Unnamed: 0     popularity   duration_ms   danceability  \
# count  114000.000000  114000.000000  1.140000e+05  114000.000000
# mean    56999.500000      33.238535  2.280292e+05       0.566800
# std     32909.109681      22.305078  1.072977e+05       0.173542
# min         0.000000       0.000000  0.000000e+00       0.000000
# 25%     28499.750000      17.000000  1.740660e+05       0.456000
# 50%     56999.500000      35.000000  2.129060e+05       0.580000
# 75%     85499.250000      50.000000  2.615060e+05       0.695000
# max    113999.000000     100.000000  5.237295e+06       0.985000
#
#               energy            key       loudness           mode  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean        0.641383       5.309140      -8.258960       0.637553
# std         0.251529       3.559987       5.029337       0.480709
# min         0.000000       0.000000     -49.531000       0.000000
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
#make list to be used in the x and y coordinates of the bar graph
popularity_list=[]
name_list=[]  
df=pd.read_csv('https://raw.githubusercontent.com/Stone999213/final-project/main/spotify_final%20project.csv')
#sort the valuse in decending order to get the top 10 most popular artist
df=df.sort_values(by="popularity",axis=0,ascending=False)
df=df.head(10)
popularity=df["popularity"]
#artist_name=df["artists"] 
#build lists to be used by x and y coordinates of bar graph
# for i in popularity:
#   popularity_list.append(i)
# for i in artist_name:
#   name_list.append(i)
# print(name_list)   
fig, ax=plt.subplots()  
ax.set_xlabel("Artist Name")
ax.set_ylabel("Popularity Rating ")
#name_list=["Doja Cat","Olivia Rodrigo","Ed Sheeran","Bad Bunny","Glass Animals","(Doja) Cat","The Weeknd","Maneskin","(Olivia) Rodrigo","The Neighborhood"]
c=["red","blue","yellow","purple"]
bar_container=ax.bar(name_list,popularity_list)
ax.bar_label(bar_container,fmt="%.0f")
ax.bar(name_list,popularity_list,color=c)
ax.set_ylim(0,150)

plt.xticks(rotation=60)

ax.set_title("The artists that have songs in the top ten most popular")



plt.show()
mean=df["popularity"].mean()
median=df["popularity"].median()
mode=df["popularity"].mode()
mode=mode[0]
print("The mean of this graph is ",mean)
print("The median of this graph is ",median)
print("The mode of this graph is ",mode)
# Out:
# ['Sam Smith;Kim Petras', 'Sam Smith;Kim Petras', 'Bizarrap;Quevedo', 'David Guetta;Bebe Rexha', 'Manuel Turizo', 'Manuel Turizo', 'Manuel Turizo', 'David Guetta;Bebe Rexha', 'David Guetta;Bebe Rexha', 'Manuel Turizo']
# The mean of this graph is  98.5
# The median of this graph is  98.0
# The mode of this graph is  98

# %%
import pandas as pd
import matplotlib.pyplot as plt

  
df=pd.read_csv('https://raw.githubusercontent.com/Stone999213/final-project/main/spotify_final%20project.csv')
df
popularity=df["popularity"]
fig, ax=plt.subplots()
ax.hist(df["popularity"],bins=5,rwidth=0.7)
plt.show()
ax.set_title
mean = df["popularity"].mean()
median=df["popularity"].median()
mode=df["popularity"].mode()
mode=(mode[0])
print("this is the mean ", mean, "median: ",median, "and mode ",mode ,"of the popularity column in the Spotify dataset")
mean_dance =df["danceability"].mean()
median_dance=df["danceability"].median()
mode_dance=df["danceability"].mode()
print("this is the mean ", mean_dance, "median: ",median_dance, "and mode ",mode_dance ," of the danceability column in the Spotify dataset")
mean_energy =df["energy"].mean()
median_energy=df["energy"].median()
mode_energy=df["energy"].mode()
print("this is the ", mean_energy, "median: ",median_energy, "and mode ",mode_energy ,"of the energy column in the Spotify dataset")

mean_loud=df["loudness"].mean()
median_loud=df["loudness"].median()
mode_loud=df["loudness"].mode()
print("this is the mean ", mean_loud, "median: ",median_loud)
# Out:
# this is the mean  33.2385350877193 median:  35.0 and mode  0 of the popularity column in the Spotify dataset
# this is the mean  0.5668000657894738 median:  0.58 and mode  0    0.647
# Name: danceability, dtype: float64  of the danceability column in the Spotify dataset
# this is the  0.6413827583964912 median:  0.685 and mode  0    0.876
# Name: energy, dtype: float64 of the energy column in the Spotify dataset
# this is the mean  -8.258960368421052 median:  -7.004

# %%
from matplotlib.figure import LayoutEngine
import pandas as pd
import matplotlib.pyplot as plt
#make list to be used in the x and y coordinates of the bar graph
#This is bar graph depicting the numbers of times the artist had songs in the 10 ten list.

artist_list=[]
artist_count_list=[]
name_list=[]  
df=pd.read_csv('https://raw.githubusercontent.com/Stone999213/final-project/main/spotify_final%20project.csv')
#sort the values in decending order to get the top 10 most popular artist
df=df.sort_values(by="popularity",axis=0,ascending=False)
df=df.head(10)
popularity=df["popularity"]
artist_name=df["artists"].sort_values()
print(artist_name)
#create new data frame based of the occurences of number of times songs of artist's occured in the top 10
# of the original data frame 
df1=pd.DataFrame({"x":[1,3,4,2],"y":["Bizarrap","David Guetta;","Manuel Turizo","Sam Smith;Kim Petras"]})

fig, ax=plt.subplots()
ax.pie(df1["x"],labels=df1["y"],colors=["red","blue","green","yellow"],explode=[.02,.02,.04,.02],autopct="%1.1f%%")
       
ax.set_title("pie chart of artist's songs appearancee in the top 10 most popular")
# Out:
# 51664           Bizarrap;Quevedo
# 81210    David Guetta;Bebe Rexha
# 30003    David Guetta;Bebe Rexha
# 20008    David Guetta;Bebe Rexha
# 89411              Manuel Turizo
# 68303              Manuel Turizo
# 88410              Manuel Turizo
# 67356              Manuel Turizo
# 20001       Sam Smith;Kim Petras
# 81051       Sam Smith;Kim Petras
# Name: artists, dtype: object
# Text(0.5, 1.0, "pie chart of artist's songs appearancee in the top 10 most popular")

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('https://raw.githubusercontent.com/Stone999213/final-project/main/spotify_final%20project.csv')

df=df.head(200)
fig, ax=plt.subplots() 
popularity=df["popularity"]
ax.boxplot(popularity)
ax.set_ylabel("Popularity Rating")
ax.set_title("Box Graph of Popularity")
mean=df["popularity"].mean()
median=df["popularity"].median()
plt.show()
print("The average popularity of songs on the spotify data set is  ",mean)
print("The median of the popularity for the songs is ",median)
# Out:
# The average popularity of songs on the spotify data set is   42.5
# The median of the popularity for the songs is  54.0
